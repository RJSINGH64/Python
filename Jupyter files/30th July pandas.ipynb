# %%
import pandas as pd

# %%
df=pd.read_csv(r"D:\Downloaded files\AgentLogingReport.csv")
df
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
# [1000 rows x 6 columns]

# %%
df.head(1)
# Out:
#    SL No               Agent       Date Login Time Logout Time  Duration
# 0      1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39  02:04:10

# %%
df.tail(4)
# Out:
#      SL No           Agent       Date Login Time Logout Time   Duration
# 996    997         Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998  Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999    Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000           Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20

# %%
df["Date"]
# Out:
# 0      30-Jul-22
# 1      30-Jul-22
# 2      30-Jul-22
# 3      30-Jul-22
# 4      30-Jul-22
#          ...
# 995    20-Jul-22
# 996    20-Jul-22
# 997    20-Jul-22
# 998    20-Jul-22
# 999    01-Jul-22
# Name: Date, Length: 1000, dtype: object

# %%
type(df["Date"])
# Out:
# pandas.core.series.Series

# %%
df.dtypes
# Out:
# SL No           int64
# Agent          object
# Date           object
# Login Time     object
# Logout Time    object
# Duration       object
# dtype: object

# %%
df[["Date",'Duration',"Agent","Logout Time"]]
# Out:
#           Date   Duration               Agent Logout Time
# 0    30-Jul-22   02:04:10  Shivananda Sonwane    17:39:39
# 1    30-Jul-22   00:00:17      Khushboo Priya    15:07:16
# 2    30-Jul-22   02:26:42       Nandani Gupta    17:31:07
# 3    30-Jul-22   00:45:06     Hrisikesh Neogi    15:19:35
# 4    30-Jul-22   01:08:36              Mukesh    15:11:52
# ..         ...        ...                 ...         ...
# 995  20-Jul-22   05:58:37        Manjunatha A    15:02:28
# 996  20-Jul-22   06:00:43             Bharath    15:01:32
# 997  20-Jul-22   05:27:34      Khushboo Priya    14:26:55
# 998  20-Jul-22   05:16:38        Nishtha Jain    14:00:33
# 999  01-Jul-22  514:08:20               Tarun    12:01:07
#
# [1000 rows x 4 columns]

# %%
df
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
# [1000 rows x 6 columns]

# %%
type(df.describe())
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Out:
#              SL No
# count  1000.000000
# mean    500.500000
# std     288.819436
# min       1.000000
# 25%     250.750000
# 50%     500.500000
# 75%     750.250000
# max    1000.000000

# %%
df1=pd.read_excel(r"C:\Users\RJ\Desktop\Dataset\Online Retail (1).xlsx")

# %%
df1
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df1.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
d=df1[['Quantity','UnitPrice']]

# %%
d.tail(2)
# Out:
#         Quantity  UnitPrice
# 541907         4       4.15
# 541908         3       4.95

# %%
type(df1.dtypes=='object')
# Out:
# pandas.core.series.Series

# %%
df1[df1.dtypes[df1.dtypes=='object'].index].describe()
# Out:
#         InvoiceNo StockCode                         Description  \
# count      541909    541909                              540455
# unique      25900      4070                                4223
# top        573585    85123A  WHITE HANGING HEART T-LIGHT HOLDER
# freq         1114      2313                                2369
#
#                Country
# count           541909
# unique              38
# top     United Kingdom
# freq            495478

# %%
df1[df1.dtypes[df1.dtypes=="float64"].index]
# Out:
#         UnitPrice  CustomerID
# 0            2.55     17850.0
# 1            3.39     17850.0
# 2            2.75     17850.0
# 3            3.39     17850.0
# 4            3.39     17850.0
# ...           ...         ...
# 541904       0.85     12680.0
# 541905       2.10     12680.0
# 541906       4.15     12680.0
# 541907       4.15     12680.0
# 541908       4.95     12680.0
#
# [541909 rows x 2 columns]

# %%
df1["UnitPrice"][:40:2]
# Out:
# 0     2.55
# 2     2.75
# 4     3.39
# 6     4.25
# 8     1.85
# 10    2.10
# 12    3.75
# 14    4.25
# 16    9.95
# 18    5.95
# 20    7.95
# 22    4.95
# 24    4.95
# 26    3.75
# 28    3.75
# 30    0.65
# 32    1.25
# 34    2.95
# 36    1.95
# 38    0.85
# Name: UnitPrice, dtype: float64

# %%
df1.UnitPrice[:40:2]
# Out:
# 0     2.55
# 2     2.75
# 4     3.39
# 6     4.25
# 8     1.85
# 10    2.10
# 12    3.75
# 14    4.25
# 16    9.95
# 18    5.95
# 20    7.95
# 22    4.95
# 24    4.95
# 26    3.75
# 28    3.75
# 30    0.65
# 32    1.25
# 34    2.95
# 36    1.95
# 38    0.85
# Name: UnitPrice, dtype: float64

# %%
df1
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df1['category1']='rajat'

# %%
df1
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country category1
# ...

# %%
df1["UnitPrice"].isnull()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 541904    False
# 541905    False
# 541906    False
# 541907    False
# 541908    False
# Name: UnitPrice, Length: 541909, dtype: bool

# %%
df1.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country', 'category1'],
#       dtype='object')

# %%
d
# Out:
#         Quantity  UnitPrice
# 0              6       2.55
# 1              6       3.39
# 2              8       2.75
# 3              6       3.39
# 4              6       3.39
# ...          ...        ...
# 541904        12       0.85
# 541905         6       2.10
# 541906         4       4.15
# 541907         4       4.15
# 541908         3       4.95
#
# [541909 rows x 2 columns]

# %%
df3=pd.read_excel(r"C:\Users\RJ\Desktop\Dataset\Dress Sales.csv.xlsx")

# %%
df3
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 0    1006032852       2114       2274                 2491
# 1    1212192089        151        275                  570
# 2    1190380701          6          7                    7
# 3     966005983       1005       1128                 1326
# 4     876339541        996       1175                 1304
# ..          ...        ...        ...                  ...
# 495   713391965          0          0                    0
# 496   722565148          0          0                    0
# 497   532874347          0          0                    0
# 498   655464934          0          0                    0
# 499   919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 0                   2660                 2727                 2887
# 1                    750                  813                 1066
# ...

# %%
df3.columns
# Out:
# Index([         'Dress_ID',         '29/8/2013',         '31/8/2013',
#        2013-02-09 00:00:00, 2013-04-09 00:00:00, 2013-06-09 00:00:00,
#        2013-08-09 00:00:00, 2013-10-09 00:00:00, 2013-12-09 00:00:00,
#                '14/9/2013',         '16/9/2013',         '18/9/2013',
#                '20/9/2013',         '22/9/2013',         '24/9/2013',
#                '26/9/2013',         '28/9/2013',         '30/9/2013',
#        2013-02-10 00:00:00, 2013-04-10 00:00:00, 2013-06-10 00:00:00,
#        2010-08-10 00:00:00, 2013-10-10 00:00:00, 2013-12-10 00:00:00],
#       dtype='object')

# %%
df3.isnull()
# Out:
#      Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  2013-04-09 00:00:00  \
# 0       False      False      False                False                False
# 1       False      False      False                False                False
# 2       False      False      False                False                False
# 3       False      False      False                False                False
# 4       False      False      False                False                False
# ..        ...        ...        ...                  ...                  ...
# 495     False      False      False                False                False
# 496     False      False      False                False                False
# 497     False      False      False                False                False
# 498     False      False      False                False                False
# 499     False      False      False                False                False
#
# ...

# %%
df1
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country category1
# ...

# %%
df1[["UnitPrice",'InvoiceNo']]
# Out:
#         UnitPrice InvoiceNo
# 0            2.55    536365
# 1            3.39    536365
# 2            2.75    536365
# 3            3.39    536365
# 4            3.39    536365
# ...           ...       ...
# 541904       0.85    581587
# 541905       2.10    581587
# 541906       4.15    581587
# 541907       4.15    581587
# 541908       4.95    581587
#
# [541909 rows x 2 columns]

# %%
df1[df1["UnitPrice"]==max(df1["UnitPrice"])]['InvoiceNo']
# Out:
# 222681    C556445
# Name: InvoiceNo, dtype: object

# %%
len(df1[df1["Country"]=="France"])
# Out:
# 8557

# %%
df1[df1["UnitPrice"] >2]['Country']
# Out:
# 0         United Kingdom
# 1         United Kingdom
# 2         United Kingdom
# 3         United Kingdom
# 4         United Kingdom
#                ...
# 541903            France
# 541905            France
# 541906            France
# 541907            France
# 541908            France
# Name: Country, Length: 286469, dtype: object

# %%
df3
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 0    1006032852       2114       2274                 2491
# 1    1212192089        151        275                  570
# 2    1190380701          6          7                    7
# 3     966005983       1005       1128                 1326
# 4     876339541        996       1175                 1304
# ..          ...        ...        ...                  ...
# 495   713391965          0          0                    0
# 496   722565148          0          0                    0
# 497   532874347          0          0                    0
# 498   655464934          0          0                    0
# 499   919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 0                   2660                 2727                 2887
# 1                    750                  813                 1066
# ...

# %%
df
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
# [1000 rows x 6 columns]

# %%
df1[(df1["Quantity"]>5) & (df1["UnitPrice"]>2)]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541879    581585     22726           ALARM CLOCK BAKELIKE GREEN         8
# 541890    581586     22061  LARGE CAKE STAND  HANGING STRAWBERY         8
# 541892    581586     21217        RED RETROSPOT ROUND CAKE TINS        24
# 541893    581586     20685                DOORMAT RED RETROSPOT        10
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
#
#                InvoiceDate  UnitPrice  CustomerID         Country category1
# ...

# %%
df3
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 0    1006032852       2114       2274                 2491
# 1    1212192089        151        275                  570
# 2    1190380701          6          7                    7
# 3     966005983       1005       1128                 1326
# 4     876339541        996       1175                 1304
# ..          ...        ...        ...                  ...
# 495   713391965          0          0                    0
# 496   722565148          0          0                    0
# 497   532874347          0          0                    0
# 498   655464934          0          0                    0
# 499   919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 0                   2660                 2727                 2887
# 1                    750                  813                 1066
# ...

# %%
df
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
# [1000 rows x 6 columns]

# %%
df1
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country category1
# ...

# %%
df1[['UnitPrice','InvoiceDate',"Quantity"]]
# Out:
#         UnitPrice         InvoiceDate  Quantity
# 0            2.55 2010-12-01 08:26:00         6
# 1            3.39 2010-12-01 08:26:00         6
# 2            2.75 2010-12-01 08:26:00         8
# 3            3.39 2010-12-01 08:26:00         6
# 4            3.39 2010-12-01 08:26:00         6
# ...           ...                 ...       ...
# 541904       0.85 2011-12-09 12:50:00        12
# 541905       2.10 2011-12-09 12:50:00         6
# 541906       4.15 2011-12-09 12:50:00         4
# 541907       4.15 2011-12-09 12:50:00         4
# 541908       4.95 2011-12-09 12:50:00         3
#
# [541909 rows x 3 columns]

# %%
df1[df1.dtypes[df1.dtypes=="object"].index].describe()
# Out:
#         InvoiceNo StockCode                         Description  \
# count      541909    541909                              540455
# unique      25900      4070                                4223
# top        573585    85123A  WHITE HANGING HEART T-LIGHT HOLDER
# freq         1114      2313                                2369
#
#                Country category1
# count           541909    541909
# unique              38         1
# top     United Kingdom     rajat
# freq            495478    541909

# %%
df1
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country category1
# ...

# %%
df1[(df1["UnitPrice"]>2.46 ) & (df1["InvoiceNo"]==536365)]
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country category1
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom     rajat
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     rajat
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom     rajat
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     rajat
# ...

# %%
df1
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country category1
# ...

# %%
df1[(df1["UnitPrice"]>2) & (df1['Country']=="France")]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 26        536370     22728            ALARM CLOCK BAKELIKE PINK        24
# 27        536370     22727            ALARM CLOCK BAKELIKE RED         24
# 28        536370     22726           ALARM CLOCK BAKELIKE GREEN        12
# 33        536370     21035      SET/2 RED RETROSPOT TEA TOWELS         18
# 34        536370     22326  ROUND SNACK BOXES SET OF4 WOODLAND         24
# ...          ...       ...                                  ...       ...
# 541903    581587     23256          CHILDRENS CUTLERY SPACEBOY          4
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country category1
# ...

# %%
df1.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# category1              object
# dtype: object

# %%
df1[["UnitPrice",'Quantity']].isnull()
# Out:
#         UnitPrice  Quantity
# 0           False     False
# 1           False     False
# 2           False     False
# 3           False     False
# 4           False     False
# ...           ...       ...
# 541904      False     False
# 541905      False     False
# 541906      False     False
# 541907      False     False
# 541908      False     False
#
# [541909 rows x 2 columns]

# %%
df
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
# [1000 rows x 6 columns]

# %%
df
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
# [1000 rows x 6 columns]

# %%
date=pd.to_datetime(df['Date'])

# %%
type(date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df["Convert_into_date"]=date

# %%
df
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration  \
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
#     Convert_into_date
# 0          2022-07-30
# ...

# %%
df["year"]=df["Convert_into_date"].dt.year

# %%
df
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration  \
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
#     Convert_into_date  year
# ...

# %%
df["day"]=df['Convert_into_date'].dt.day

# %%
df
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration  \
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
#     Convert_into_date  year  month  week  day
# ...

# %%
df
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration  \
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
#     Convert_into_date  year  month  week  day
# ...

# %%
df[df["year"]==2022]
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration  \
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
#     Convert_into_date  year  month  week  day
# ...

# %%
df["Agent"].value_counts()
# Out:
# Dibyanshu                 208
# Deepranjan Gupta           58
# Ishawant Kumar             49
# Saurabh Shukla             40
# Hrisikesh Neogi            37
# Anurag Tiwari              37
# Shivan K                   36
# Mahesh Sarade              36
# Shubham Sharma             35
# Prabir Kumar Satapathy     26
# Sowmiya Sivakumar          24
# Harikrishnan Shaji         23
# Sanjeev Kumar              20
# Wasim                      20
# Ayushi Mishra              18
# Prerna Singh               18
# Nishtha Jain               18
# Khushboo Priya             18
# Prateek _iot               17
# Madhulika G                17
# Boktiar Ahmed Bappy        17
# Jawala Prakash             16
# Shiva Srivastava           15
# Shivananda Sonwane         15
# Mithun S                   14
# Chaitra K Hiremath         13
# Muskan Garg                12
# Rishav Dash                12
# Jaydeep Dixit              11
# Nandani Gupta              11
# Sudhanshu Kumar            11
# ...

# %%
df
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration  \
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
#     Convert_into_date  year  month  week  day
# ...

# %%
df[df["month"]==7]
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration  \
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
#     Convert_into_date  year  month  week  day
# ...

# %%
df.head(4)
# Out:
#    SL No               Agent       Date Login Time Logout Time  Duration  \
# 0      1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39  02:04:10
# 1      2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16  00:00:17
# 2      3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07  02:26:42
# 3      4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35  00:45:06
#
#   Convert_into_date  year  month  week  day
# 0        2022-07-30  2022      7    30   30
# 1        2022-07-30  2022      7    30   30
# 2        2022-07-30  2022      7    30   30
# 3        2022-07-30  2022      7    30   30

# %%
df.columns
# Out:
# Index(['SL No', 'Agent', 'Date', 'Login Time', 'Logout Time', 'Duration',
#        'Convert_into_date', 'year', 'month', 'week', 'day'],
#       dtype='object')

# %%
df1
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country category1
# ...

# %%
df
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration  \
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
#     Convert_into_date  year  month  week  day
# ...

# %%
df1[(df1["UnitPrice"]>2) & (df1["Quantity"]>6)]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 12        536367     22749    FELTCRAFT PRINCESS CHARLOTTE DOLL         8
# 26        536370     22728            ALARM CLOCK BAKELIKE PINK        24
# 27        536370     22727            ALARM CLOCK BAKELIKE RED         24
# 28        536370     22726           ALARM CLOCK BAKELIKE GREEN        12
# ...          ...       ...                                  ...       ...
# 541874    581585     23084                   RABBIT NIGHT LIGHT        12
# 541879    581585     22726           ALARM CLOCK BAKELIKE GREEN         8
# 541890    581586     22061  LARGE CAKE STAND  HANGING STRAWBERY         8
# 541892    581586     21217        RED RETROSPOT ROUND CAKE TINS        24
# 541893    581586     20685                DOORMAT RED RETROSPOT        10
#
#                InvoiceDate  UnitPrice  CustomerID         Country category1
# ...

# %%
df1['UnitPrice'].value_counts()
# Out:
# 1.25      50496
# 1.65      38181
# 0.85      28497
# 2.95      27768
# 0.42      24533
#           ...
# 84.21         1
# 46.86         1
# 28.66         1
# 156.45        1
# 224.69        1
# Name: UnitPrice, Length: 1630, dtype: int64

# %%
df
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration  \
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
#     Convert_into_date  year  month  week  day
# ...

# %%
df=df.drop("day",axis=1)

# %%
df
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration  \
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
#     Convert_into_date  year  month  week
# ...

# %%
df.drop("month",axis=1,inplace=True)

# %%
df
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration  \
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
#     Convert_into_date  year  week
# ...

# %%
df.drop(1,inplace=True)

# %%
df
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration  \
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# 5        6   Sowmiya Sivakumar  30-Jul-22   14:03:11    15:05:37   01:02:26
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
#     Convert_into_date  year  week
# ...

# %%
df.loc[2:10:2]
# Out:
#     SL No          Agent       Date Login Time Logout Time  Duration  \
# 2       3  Nandani Gupta  30-Jul-22   15:04:24    17:31:07  02:26:42
# 4       5         Mukesh  30-Jul-22   14:03:15    15:11:52  01:08:36
# 6       7   Manjunatha A  30-Jul-22   14:00:12    15:08:29  01:08:16
# 8       9  Suraj S Bilgi  30-Jul-22   13:50:01    15:11:42  01:21:41
# 10     11  Anurag Tiwari  30-Jul-22   13:06:12    13:11:57  00:05:44
#
#    Convert_into_date  year  week
# 2         2022-07-30  2022    30
# 4         2022-07-30  2022    30
# 6         2022-07-30  2022    30
# 8         2022-07-30  2022    30
# 10        2022-07-30  2022    30

# %%
df1.loc[0:4,["UnitPrice","Quantity"]]
# Out:
#    UnitPrice  Quantity
# 0       2.55         6
# 1       3.39         6
# 2       2.75         8
# 3       3.39         6
# 4       3.39         6

# %%
df1.iloc[0:4, 0:3]
# Out:
#   InvoiceNo StockCode                          Description
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1    536365     71053                  WHITE METAL LANTERN
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE

# %%
df
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration  \
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# 5        6   Sowmiya Sivakumar  30-Jul-22   14:03:11    15:05:37   01:02:26
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
#     Convert_into_date  year  week
# ...

# %%
df1.loc[2:6, ["Quantity","UnitPrice"]]
# Out:
#    Quantity  UnitPrice
# 2         8       2.75
# 3         6       3.39
# 4         6       3.39
# 5         2       7.65
# 6         6       4.25

# %%
df1[df1["UnitPrice"]>5]
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 5         536365     22752    SET 7 BABUSHKA NESTING BOXES         2
# 16        536367     22622  BOX OF VINTAGE ALPHABET BLOCKS         2
# 17        536367     21754        HOME BUILDING BLOCK WORD         3
# 18        536367     21755        LOVE BUILDING BLOCK WORD         3
# 19        536367     21777     RECIPE BOX WITH METAL HEART         4
# ...          ...       ...                             ...       ...
# 541855    581580     21351        CINAMMON & ORANGE WREATH         1
# 541858    581580     79321                   CHILLI LIGHTS         2
# 541878    581585     23356           LOVE HOT WATER BOTTLE         3
# 541892    581586     21217   RED RETROSPOT ROUND CAKE TINS        24
# 541893    581586     20685           DOORMAT RED RETROSPOT        10
#
#                InvoiceDate  UnitPrice  CustomerID         Country category1
# ...

# %%
df4=df1[df1.dtypes[(df1.dtypes=="float64") | (df1.dtypes=="int")].index]

# %%
df5=df4[df4<1]

# %%
df6=df5.dropna()

# %%
df6
# Out:
#         UnitPrice  CustomerID
# 5            7.65     17850.0
# 16           9.95     13047.0
# 17           5.95     13047.0
# 18           5.95     13047.0
# 19           7.95     13047.0
# ...           ...         ...
# 541855       6.75     12748.0
# 541858       5.75     12748.0
# 541878       5.95     15804.0
# 541892       8.95     13113.0
# 541893       7.08     13113.0
#
# [53346 rows x 2 columns]

# %%
df5.dropna(thresh=3)
# Out:
# Empty DataFrame
# Columns: [UnitPrice, CustomerID]
# Index: []

# %%
df5.dropna(thresh=2)
# Out:
#         UnitPrice  CustomerID
# 5            7.65     17850.0
# 16           9.95     13047.0
# 17           5.95     13047.0
# 18           5.95     13047.0
# 19           7.95     13047.0
# ...           ...         ...
# 541855       6.75     12748.0
# 541858       5.75     12748.0
# 541878       5.95     15804.0
# 541892       8.95     13113.0
# 541893       7.08     13113.0
#
# [53346 rows x 2 columns]

# %%
df5.fillna(value=4)
# Out:
#         UnitPrice  CustomerID
# 0             4.0     17850.0
# 1             4.0     17850.0
# 2             4.0     17850.0
# 3             4.0     17850.0
# 4             4.0     17850.0
# ...           ...         ...
# 541904        4.0     12680.0
# 541905        4.0     12680.0
# 541906        4.0     12680.0
# 541907        4.0     12680.0
# 541908        4.0     12680.0
#
# [541909 rows x 2 columns]

# %%
df5
# Out:
#         UnitPrice  CustomerID
# 0             NaN     17850.0
# 1             NaN     17850.0
# 2             NaN     17850.0
# 3             NaN     17850.0
# 4             NaN     17850.0
# ...           ...         ...
# 541904        NaN     12680.0
# 541905        NaN     12680.0
# 541906        NaN     12680.0
# 541907        NaN     12680.0
# 541908        NaN     12680.0
#
# [541909 rows x 2 columns]

# %%
df5.fillna(value=df5["UnitPrice"].mean())
# Out:
#         UnitPrice  CustomerID
# 0          18.046     17850.0
# 1          18.046     17850.0
# 2          18.046     17850.0
# 3          18.046     17850.0
# 4          18.046     17850.0
# ...           ...         ...
# 541904     18.046     12680.0
# 541905     18.046     12680.0
# 541906     18.046     12680.0
# 541907     18.046     12680.0
# 541908     18.046     12680.0
#
# [541909 rows x 2 columns]

# %%
df5.dropna(thresh=2)
# Out:
#         UnitPrice  CustomerID
# 5            7.65     17850.0
# 16           9.95     13047.0
# 17           5.95     13047.0
# 18           5.95     13047.0
# 19           7.95     13047.0
# ...           ...         ...
# 541855       6.75     12748.0
# 541858       5.75     12748.0
# 541878       5.95     15804.0
# 541892       8.95     13113.0
# 541893       7.08     13113.0
#
# [53346 rows x 2 columns]

# %%
df5["UnitPrice"].mean()
# Out:
# 0.4184338013429842

# %%
df5
# Out:
#         UnitPrice  CustomerID
# 0             NaN     17850.0
# 1             NaN     17850.0
# 2             NaN     17850.0
# 3             NaN     17850.0
# 4             NaN     17850.0
# ...           ...         ...
# 541904        NaN     12680.0
# 541905        NaN     12680.0
# 541906        NaN     12680.0
# 541907        NaN     12680.0
# 541908        NaN     12680.0
#
# [541909 rows x 2 columns]

# %%
df1
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country category1
# ...

# %%
df1.groupby()["UnitPrice"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[292], line 1
# ----> 1 df1.groupby("Week")["UnitPrice"]
#
# File E:\AnacondaDistribution\Lib\site-packages\pandas\core\frame.py:8402, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8399     raise TypeError("You have to supply one of 'by' and 'level'")
#    8400 axis = self._get_axis_number(axis)
# -> 8402 return DataFrameGroupBy(
#    8403     obj=self,
#    8404     keys=by,
#    8405     axis=axis,
#    8406     level=level,
#    8407     as_index=as_index,
#    8408     sort=sort,
#    8409     group_keys=group_keys,
#    8410     squeeze=squeeze,
#    8411     observed=observed,
#    8412     dropna=dropna,
#    8413 )
#
# ...

# %%
df
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration  \
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# 5        6   Sowmiya Sivakumar  30-Jul-22   14:03:11    15:05:37   01:02:26
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
#     Convert_into_date  year  week
# ...

# %%
pd.dat
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country category1
# ...

# %%
date1=pd.to_datetime(df1["InvoiceDate"])

# %%
df1["Date"]=date1

# %%
df1
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country category1  \
# ...

# %%
df1["Year_of_Invoice"]=df1["Date"].dt.year

# %%
df1
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country category1  \
# ...

# %%
df1.groupby("Year_of_Invoice")["UnitPrice"].mean()
# Out:
# Year_of_Invoice
# 2010    6.132644
# 2011    4.481693
# Name: UnitPrice, dtype: float64

# %%
df1.groupby("Year_of_Invoice")["Quantity"].mean()
# Out:
# Year_of_Invoice
# 2010    8.056025
# 2011    9.679517
# Name: Quantity, dtype: float64

# %%
df1.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country', 'category1', 'Date',
#        'Year_of_Invoice'],
#       dtype='object')

# %%
df1[["Country","CustomerID"]]
# Out:
#                Country  CustomerID
# 0       United Kingdom     17850.0
# 1       United Kingdom     17850.0
# 2       United Kingdom     17850.0
# 3       United Kingdom     17850.0
# 4       United Kingdom     17850.0
# ...                ...         ...
# 541904          France     12680.0
# 541905          France     12680.0
# 541906          France     12680.0
# 541907          France     12680.0
# 541908          France     12680.0
#
# [541909 rows x 2 columns]

# %%
df1[df1.dtypes[df1.dtypes=="object"].index]
# Out:
#        InvoiceNo StockCode                          Description  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1         536365     71053                  WHITE METAL LANTERN
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# ...          ...       ...                                  ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT
#
#                Country category1
# 0       United Kingdom     rajat
# 1       United Kingdom     rajat
# 2       United Kingdom     rajat
# 3       United Kingdom     rajat
# ...

# %%
df
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration  \
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# 5        6   Sowmiya Sivakumar  30-Jul-22   14:03:11    15:05:37   01:02:26
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
#     Convert_into_date  year  week
# ...

# %%
df1
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country category1  \
# ...

# %%
df1.dtypes[("InvoiceNo")]
# Out:
# dtype('O')

# %%
df1.dtypes
# Out:
# InvoiceNo                  object
# StockCode                  object
# Description                object
# Quantity                    int64
# InvoiceDate        datetime64[ns]
# UnitPrice                 float64
# CustomerID                float64
# Country                    object
# category1                  object
# Date               datetime64[ns]
# Year_of_Invoice             int64
# dtype: object

# %%
df1
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country category1  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[345], line 1
# ----> 1 df["InvoiceNo"]=df1.InvoiceNo.str.replace("," ,"").astype(int)
#
# File E:\AnacondaDistribution\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File E:\AnacondaDistribution\Lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df1.groupby("Year_of_Invoice")["Quantity"].mean()
# Out:
# Year_of_Invoice
# 2010    8.056025
# 2011    9.679517
# Name: Quantity, dtype: float64

# %%
df1.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country', 'category1', 'Date',
#        'Year_of_Invoice'],
#       dtype='object')

# %%
df5=pd.read_csv(r"C:\Users\RJ\Desktop\Practice Resourses\AgentLogingReport.csv")

# %%
df5
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
# [1000 rows x 6 columns]

# %%
df5.dtypes
# Out:
# SL No           int64
# Agent          object
# Date           object
# Login Time     object
# Logout Time    object
# Duration       object
# dtype: object

# %%
data=pd.to_datetime(df5['Date'])

# %%
data
# Out:
# 0     2022-07-30
# 1     2022-07-30
# 2     2022-07-30
# 3     2022-07-30
# 4     2022-07-30
#          ...
# 995   2022-07-20
# 996   2022-07-20
# 997   2022-07-20
# 998   2022-07-20
# 999   2022-07-01
# Name: Date, Length: 1000, dtype: datetime64[ns]

# %%
df5["Date_of_"]=data

# %%
df5
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration  \
# 0        1  Shivananda Sonwane 2022-07-30   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya 2022-07-30   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta 2022-07-30   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi 2022-07-30   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh 2022-07-30   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A 2022-07-20   09:03:51    15:02:28   05:58:37
# 996    997             Bharath 2022-07-20   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya 2022-07-20   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain 2022-07-20   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun 2022-07-01   01:52:47    12:01:07  514:08:20
#
#       Date_of_
# 0   2022-07-30
# 1   2022-07-30
# ...

# %%
df5["day"]=df5["Date_of_"].dt.day

# %%
df5
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration  \
# 0        1  Shivananda Sonwane 2022-07-30   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya 2022-07-30   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta 2022-07-30   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi 2022-07-30   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh 2022-07-30   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A 2022-07-20   09:03:51    15:02:28   05:58:37
# 996    997             Bharath 2022-07-20   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya 2022-07-20   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain 2022-07-20   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun 2022-07-01   01:52:47    12:01:07  514:08:20
#
#       Date_of_  week  year  day
# ...

# %%
df.lock[:1000]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.lock[:1000]
#
# NameError: name 'df' is not defined
