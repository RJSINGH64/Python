# %%
#1. Read this dataset in pandas , mysql and mongodb 
2. while creting a table in mysql dont use manual approach to create it  ,always use a automation to create a table in mysql
 ## hint - use csvkit library to automate this task and to load a data in bulk in you mysql 
3. convert all the dates avaible in dataset to timestamp format in pandas and in sql you to convert it in date format
4 . Find out in this data that how many unique id's we have 
5 . which id is one of the active id that you have in whole dataset 
6 . how many of them have not logged there activity find out in terms of number of ids 
7 . Find out who is the laziest person id that we have in dataset 
8 . Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy person we have in our dataset 
9. how many person are not a regular person with respect to activity try to find out those 
10 . who is the thired most active person in this dataset find out those in pandas and in sql both . 
11 . who is the 5th most laziest person avilable in dataset find it out 
12 . what is a totla acumulative calories burn for a person find out

# %%
pip install csvkit
# Out:
# ...
#   Obtaining dependency information for csvkit from https://files.pythonhosted.org/packages/6c/84/b10374471438b12122b9050e5b8b7652a08e4286f02293c379bc93e640d5/csvkit-1.4.0-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for agate>=1.6.3 from https://files.pythonhosted.org/packages/d1/53/89b197cb472a3175d73384761a3413fd58e6b65a794c1102d148b8de87bd/agate-1.9.1-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for agate-excel>=0.2.2 from https://files.pythonhosted.org/packages/d6/6f/5d71389b715654dc636180af8b33923926f73c4cf89450813c9380cbb3cf/agate_excel-0.4.1-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for agate-dbf>=0.2.2 from https://files.pythonhosted.org/packages/d9/99/cd4729cb51d6c7de8ad00eab375021cb34b8ca132350efe401488af10483/agate_dbf-0.2.3-py2.py3-none-any.whl.metadata
# ...

# %%
import MySQLdb

# %%
# !csvsql --db mysql://root:ROCKINGRJ12345@localhost/DB1 --insert fit_bit_data.csv
# Out:
# E:\AnacondaDistribution\Lib\site-packages\agate\table\from_csv.py:67: RuntimeWarning: Error sniffing CSV dialect: Could not determine delimiter
#   kwargs['dialect'] = csv.Sniffer().sniff(contents.getvalue()[:sniff_limit])
# OperationalError: (MySQLdb.OperationalError) (1050, "Table 'fit_bit_data' already exists")
# [SQL:
# CREATE TABLE fit_bit_data (
# 	`Id` DECIMAL(38, 0) NOT NULL,
# 	`ActivityDate` DATE NOT NULL,
# 	`TotalSteps` DECIMAL(38, 0) NOT NULL,
# 	`TotalDistance` DECIMAL(38, 17) NOT NULL,
# 	`TrackerDistance` DECIMAL(38, 17) NOT NULL,
# 	`LoggedActivitiesDistance` DECIMAL(38, 15) NOT NULL,
# 	`VeryActiveDistance` DECIMAL(38, 17) NOT NULL,
# 	`ModeratelyActiveDistance` DECIMAL(38, 16) NOT NULL,
# 	`LightActiveDistance` DECIMAL(38, 17) NOT NULL,
# 	`SedentaryActiveDistance` DECIMAL(38, 17) NOT NULL,
# 	`VeryActiveMinutes` DECIMAL(38, 0) NOT NULL,
# 	`FairlyActiveMinutes` DECIMAL(38, 0) NOT NULL,
# 	`LightlyActiveMinutes` DECIMAL(38, 0) NOT NULL,
# ...

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\RJ\Desktop\Practice Resourses\fit_bit_data.csv")

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  ...  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0    1503960366    3/25/2016       11004  ...                   205               804      1819
# 1    1503960366    3/26/2016       17609  ...                   274               588      2154
# 2    1503960366    3/27/2016       12736  ...                   268               605      1944
# 3    1503960366    3/28/2016       13231  ...                   224              1080      1932
# 4    1503960366    3/29/2016       12041  ...                   243               763      1886
# ..          ...          ...         ...  ...                   ...               ...       ...
# 452  8877689391     4/8/2016       23014  ...                   359               982      4196
# 453  8877689391     4/9/2016       16470  ...                   289              1052      3841
# 454  8877689391    4/10/2016       28497  ...                   211              1055      4526
# ...

# %%
pip install pymongo[srv]
# Out:
# ...
#
#   Obtaining dependency information for pymongo[srv] from https://files.pythonhosted.org/packages/9d/10/f01efcd8f34cce0adb59c9feebdd092bd7305d35e77400e9999557112ade/pymongo-4.6.2-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for dnspython<3.0.0,>=1.16.0 from https://files.pythonhosted.org/packages/87/a1/8c5287991ddb8d3e4662f71356d9656d91ab3a36618c3dd11b280df0d255/dnspython-2.6.1-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/307.7 kB ? eta -:--:--
#    --------------- ------------------------ 122.9/307.7 kB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  307.2/307.7 kB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  307.2/307.7 kB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 307.7/307.7 kB 1.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/472.8 kB ? eta -:--:--
#    ------------------- -------------------- 235.5/472.8 kB 4.8 MB/s eta 0:00:01
# ...

# %%
pip install  pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymongo
import pandas as pd
client=pymongo.MongoClient("mongodb+srv://rajatksingh64:ROCKINGRJ12345@cluster1.mk1y1ia.mongodb.net/?retryWrites=true&w=majority&appName=Cluster1")
db=client.test1

# %%
df=df.to_json("D://testjson.json")

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\RJ\Desktop\FitBit data.csv")

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   04-08-2016       23014      20.389999        20.389999
# 453  8877689391   04-09-2016       16470       8.070000         8.070000
# 454  8877689391   04-10-2016       28497      27.530001        27.530001
# 455  8877689391   04-11-2016       10622       8.060000         8.060000
# 456  8877689391   04-12-2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
data=pd.to_datetime(df["ActivityDate"])

# %%
df["date_time_timestamp"]=data

# %%
df.drop("ActivityDate",axis=1)
# Out:
#              Id  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366       11004       7.110000         7.110000
# 1    1503960366       17609      11.550000        11.550000
# 2    1503960366       12736       8.530000         8.530000
# 3    1503960366       13231       8.930000         8.930000
# 4    1503960366       12041       7.850000         7.850000
# ..          ...         ...            ...              ...
# 452  8877689391       23014      20.389999        20.389999
# 453  8877689391       16470       8.070000         8.070000
# 454  8877689391       28497      27.530001        27.530001
# 455  8877689391       10622       8.060000         8.060000
# 456  8877689391        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# ...

# %%
(df.groupby("Id")["Calories"].sum())
# Out:
# Id
# 1503960366    34128
# 1624580081    25705
# 1644430081    29164
# 1844505072    19391
# 1927972279    27048
# 2022484408    29704
# 2026352035    16266
# 2320127002    18385
# 2347167796    30320
# 2873212765    20349
# 2891001357    18187
# 3372868164    18603
# 3977333714    16777
# 4020332650    98412
# 4057192912    60913
# 4319703577    23931
# 4388161847    14442
# 4445114986    31617
# 4558609924    21962
# 4702921684    42322
# 5553957443    21630
# 5577150313    36303
# 6117666160    20993
# 6290855005    21656
# 6391747486    15868
# 6775888955    24523
# 6962181067    29249
# 7007744171    31525
# 7086361926    26124
# 8053475328    31825
# 8253242879    17556
# 8378563200    40274
# 8583815059    19130
# 8792009665    24884
# 8877689391    41414
# Name: Calories, dtype: int64

# %%
import pandas as pd
import mysql as conn

# %%
df0=pd.read_excel(r"C:\Users\RJ\Desktop\Practice Resourses\Superstore_USA.xlsx")

# %%
df0
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
df.to_csv("D://df.csv")

# %%
df1=pd.read_csv(r"D:\df0.csv")

# %%
df1
# Out:
#       Unnamed: 0  Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 0              0   18606  Not Specified      0.01        2.88           0.50
# 1              1   20847           High      0.01        2.84           0.93
# 2              2   23086  Not Specified      0.03        6.68           6.15
# 3              3   23087  Not Specified      0.01        5.68           3.60
# 4              4   23088  Not Specified      0.00      205.99           2.50
# ...          ...     ...            ...       ...         ...            ...
# 9421        9421   20275       Critical      0.06       35.89          14.72
# 9422        9422   20276       Critical      0.00        3.34           7.49
# 9423        9423   24491  Not Specified      0.08      550.98          45.70
# 9424        9424   25914           High      0.10      105.98          13.99
# 9425        9425   24492  Not Specified      0.09        7.78           2.50
#
# ...

# %%
import csvkit

# %%
# !csvsql --db mysql://root:ROCKINGRJ12345@localhost/DB1 --insert df.csv
# Out:
# E:\AnacondaDistribution\Lib\site-packages\agate\utils.py:272: UnnamedColumnWarning: Column 0 has no name. Using "a".
#   warn_unnamed_column(i, new_value)

# %%
df0=df

# %%
df[df["Status"]=="Returned"].value_counts()
# Out:
# Unnamed: 0  Order ID  Status
# 0           65        Returned    1
# 1085        152504    Returned    1
# 1095        153144    Returned    1
# 1094        153081    Returned    1
# 1093        153016    Returned    1
#                                  ..
# 542         59776     Returned    1
# 541         59683     Returned    1
# 540         59680     Returned    1
# 539         59652     Returned    1
# 1633        182906    Returned    1
# Length: 1634, dtype: int64

# %%
df0
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
df0[df0["Order ID"]==152504]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order Priority, Discount, Unit Price, Shipping Cost, Customer ID, Customer Name, Ship Mode, Customer Segment, Product Category, Product Sub-Category, Product Container, Product Name, Product Base Margin, Region, State or Province, City, Postal Code, Order Date, Ship Date, Profit, Quantity ordered new, Sales, Order ID]
# Index: []
#
# [0 rows x 24 columns]

# %%
result=pd.merge(df0,df,on="Order ID",how="inner")

# %%
result
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     1359            Low      0.05        5.85           2.27           21
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 3     5055           High      0.02        3.28           5.00          117
# 4     5573            Low      0.02       11.97           5.81          272
# ..     ...            ...       ...         ...            ...          ...
# 93     986  Not Specified      0.06       37.94           5.08         3075
# 94     987  Not Specified      0.10       55.29           5.08         3075
# 95    6041         Medium      0.05        4.28           6.18         3075
# 96    1910           High      0.05       14.48           1.99         3079
# 97    6625           High      0.06      128.24          12.65         3251
#
# ...

# %%
result1=df0.join(df,lsuffix='df',rsuffix='df0',how="inner")

# %%
result1
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 1629   23975           High      0.07        3.81           4.83          614
# 1630   25408           High      0.10       55.99           2.50          615
# 1631   18492  Not Specified      0.02       15.57           1.39          617
# 1632   18493  Not Specified      0.02       20.89          11.52          617
# 1633   22196       Critical      0.06       17.98           4.00          618
#
# ...

# %%
count=df0.drop_duplicates(subset="Customer Name")

# %%
count["Customer Name"].value_counts()
# Out:
# Janice Fletcher     1
# Alexander Joyner    1
# Philip Olsen        1
# Calvin Ferrell      1
# Jeff Meadows        1
#                    ..
# Cecil Berger        1
# Rita Vaughn         1
# Tonya Proctor       1
# Peggy Lanier        1
# Tammy Buckley       1
# Name: Customer Name, Length: 2703, dtype: int64

# %%
df0
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
df2=pd.read_csv(r"D:\df1.csv")

# %%
df2
# Out:
#    Unnamed: 0   Region  Manager
# 0           0  Central    Chris
# 1           1     East     Erin
# 2           2    South      Sam
# 3           3     West  William

# %%
df=df

# %%
df
# Out:
#       Unnamed: 0  Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 0              0   18606  Not Specified      0.01        2.88           0.50
# 1              1   20847           High      0.01        2.84           0.93
# 2              2   23086  Not Specified      0.03        6.68           6.15
# 3              3   23087  Not Specified      0.01        5.68           3.60
# 4              4   23088  Not Specified      0.00      205.99           2.50
# ...          ...     ...            ...       ...         ...            ...
# 9421        9421   20275       Critical      0.06       35.89          14.72
# 9422        9422   20276       Critical      0.00        3.34           7.49
# 9423        9423   24491  Not Specified      0.08      550.98          45.70
# 9424        9424   25914           High      0.10      105.98          13.99
# 9425        9425   24492  Not Specified      0.09        7.78           2.50
#
# ...

# %%
df
# Out:
#       Unnamed: 0  Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 0              0   18606  Not Specified      0.01        2.88           0.50
# 1              1   20847           High      0.01        2.84           0.93
# 2              2   23086  Not Specified      0.03        6.68           6.15
# 3              3   23087  Not Specified      0.01        5.68           3.60
# 4              4   23088  Not Specified      0.00      205.99           2.50
# ...          ...     ...            ...       ...         ...            ...
# 9421        9421   20275       Critical      0.06       35.89          14.72
# 9422        9422   20276       Critical      0.00        3.34           7.49
# 9423        9423   24491  Not Specified      0.08      550.98          45.70
# 9424        9424   25914           High      0.10      105.98          13.99
# 9425        9425   24492  Not Specified      0.09        7.78           2.50
#
# ...

# %%
df2
# Out:
#    Unnamed: 0   Region  Manager
# 0           0  Central    Chris
# 1           1     East     Erin
# 2           2    South      Sam
# 3           3     West  William

# %%
df
# Out:
#       Unnamed: 0  Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 0              0   18606  Not Specified      0.01        2.88           0.50
# 1              1   20847           High      0.01        2.84           0.93
# 2              2   23086  Not Specified      0.03        6.68           6.15
# 3              3   23087  Not Specified      0.01        5.68           3.60
# 4              4   23088  Not Specified      0.00      205.99           2.50
# ...          ...     ...            ...       ...         ...            ...
# 9421        9421   20275       Critical      0.06       35.89          14.72
# 9422        9422   20276       Critical      0.00        3.34           7.49
# 9423        9423   24491  Not Specified      0.08      550.98          45.70
# 9424        9424   25914           High      0.10      105.98          13.99
# 9425        9425   24492  Not Specified      0.09        7.78           2.50
#
# ...

# %%
manager_of_df=pd.merge(df,df1,how="inner")

# %%
manager_of_df
# Out:
#       Unnamed: 0  Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 0              0   18606  Not Specified      0.01        2.88           0.50
# 1              1   20847           High      0.01        2.84           0.93
# 2              2   23086  Not Specified      0.03        6.68           6.15
# 3              3   23087  Not Specified      0.01        5.68           3.60
# 4              4   23088  Not Specified      0.00      205.99           2.50
# ...          ...     ...            ...       ...         ...            ...
# 9421        9421   20275       Critical      0.06       35.89          14.72
# 9422        9422   20276       Critical      0.00        3.34           7.49
# 9423        9423   24491  Not Specified      0.08      550.98          45.70
# 9424        9424   25914           High      0.10      105.98          13.99
# 9425        9425   24492  Not Specified      0.09        7.78           2.50
#
# ...

# %%
def manager_of_region(a):
    if a=="central":
        return "Chris"
    elif a=="East":
        return "Erin"
    elif a=="South" :
        return "Sam"
    else:
        return "William"

# %%
df["Manager_of_region"]=df["Region"].apply(manager_of_region)

# %%
df
# Out:
#       Unnamed: 0  Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 0              0   18606  Not Specified      0.01        2.88           0.50
# 1              1   20847           High      0.01        2.84           0.93
# 2              2   23086  Not Specified      0.03        6.68           6.15
# 3              3   23087  Not Specified      0.01        5.68           3.60
# 4              4   23088  Not Specified      0.00      205.99           2.50
# ...          ...     ...            ...       ...         ...            ...
# 9421        9421   20275       Critical      0.06       35.89          14.72
# 9422        9422   20276       Critical      0.00        3.34           7.49
# 9423        9423   24491  Not Specified      0.08      550.98          45.70
# 9424        9424   25914           High      0.10      105.98          13.99
# 9425        9425   24492  Not Specified      0.09        7.78           2.50
#
# ...

# %%
df
# Out:
#       Unnamed: 0  Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 0              0   18606  Not Specified      0.01        2.88           0.50
# 1              1   20847           High      0.01        2.84           0.93
# 2              2   23086  Not Specified      0.03        6.68           6.15
# 3              3   23087  Not Specified      0.01        5.68           3.60
# 4              4   23088  Not Specified      0.00      205.99           2.50
# ...          ...     ...            ...       ...         ...            ...
# 9421        9421   20275       Critical      0.06       35.89          14.72
# 9422        9422   20276       Critical      0.00        3.34           7.49
# 9423        9423   24491  Not Specified      0.08      550.98          45.70
# 9424        9424   25914           High      0.10      105.98          13.99
# 9425        9425   24492  Not Specified      0.09        7.78           2.50
#
# ...

# %%
data=pd.to_datetime(df["Order Date"])

# %%
df["Order_Day_of"]=data.dt.day

# %%
data1=pd.to_datetime(df["Ship Date"])

# %%
df["ship_day_of"]=data1.dt.day

# %%
df
# Out:
#       Unnamed: 0  Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 0              0   18606  Not Specified      0.01        2.88           0.50
# 1              1   20847           High      0.01        2.84           0.93
# 2              2   23086  Not Specified      0.03        6.68           6.15
# 3              3   23087  Not Specified      0.01        5.68           3.60
# 4              4   23088  Not Specified      0.00      205.99           2.50
# ...          ...     ...            ...       ...         ...            ...
# 9421        9421   20275       Critical      0.06       35.89          14.72
# 9422        9422   20276       Critical      0.00        3.34           7.49
# 9423        9423   24491  Not Specified      0.08      550.98          45.70
# 9424        9424   25914           High      0.10      105.98          13.99
# 9425        9425   24492  Not Specified      0.09        7.78           2.50
#
# ...

# %%
df=df.drop("Order_Day",axis=1)

# %%
df
# Out:
#       Unnamed: 0  Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 0              0   18606  Not Specified      0.01        2.88           0.50
# 1              1   20847           High      0.01        2.84           0.93
# 2              2   23086  Not Specified      0.03        6.68           6.15
# 3              3   23087  Not Specified      0.01        5.68           3.60
# 4              4   23088  Not Specified      0.00      205.99           2.50
# ...          ...     ...            ...       ...         ...            ...
# 9421        9421   20275       Critical      0.06       35.89          14.72
# 9422        9422   20276       Critical      0.00        3.34           7.49
# 9423        9423   24491  Not Specified      0.08      550.98          45.70
# 9424        9424   25914           High      0.10      105.98          13.99
# 9425        9425   24492  Not Specified      0.09        7.78           2.50
#
# ...

# %%
df
# Out:
#       Unnamed: 0  Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 0              0   18606  Not Specified      0.01        2.88           0.50
# 1              1   20847           High      0.01        2.84           0.93
# 2              2   23086  Not Specified      0.03        6.68           6.15
# 3              3   23087  Not Specified      0.01        5.68           3.60
# 4              4   23088  Not Specified      0.00      205.99           2.50
# ...          ...     ...            ...       ...         ...            ...
# 9421        9421   20275       Critical      0.06       35.89          14.72
# 9422        9422   20276       Critical      0.00        3.34           7.49
# 9423        9423   24491  Not Specified      0.08      550.98          45.70
# 9424        9424   25914           High      0.10      105.98          13.99
# 9425        9425   24492  Not Specified      0.09        7.78           2.50
#
# ...

# %%
df["date_differnce_till_order"]=df["ship_day_of"] - df["Order_Day_of"]

# %%
df
# Out:
#       Unnamed: 0  Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 0              0   18606  Not Specified      0.01        2.88           0.50
# 1              1   20847           High      0.01        2.84           0.93
# 2              2   23086  Not Specified      0.03        6.68           6.15
# 3              3   23087  Not Specified      0.01        5.68           3.60
# 4              4   23088  Not Specified      0.00      205.99           2.50
# ...          ...     ...            ...       ...         ...            ...
# 9421        9421   20275       Critical      0.06       35.89          14.72
# 9422        9422   20276       Critical      0.00        3.34           7.49
# 9423        9423   24491  Not Specified      0.08      550.98          45.70
# 9424        9424   25914           High      0.10      105.98          13.99
# 9425        9425   24492  Not Specified      0.09        7.78           2.50
#
# ...

# %%
df=df.drop("date_differnce_",axis=1)

# %%
df
# Out:
#       Unnamed: 0  Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 0              0   18606  Not Specified      0.01        2.88           0.50
# 1              1   20847           High      0.01        2.84           0.93
# 2              2   23086  Not Specified      0.03        6.68           6.15
# 3              3   23087  Not Specified      0.01        5.68           3.60
# 4              4   23088  Not Specified      0.00      205.99           2.50
# ...          ...     ...            ...       ...         ...            ...
# 9421        9421   20275       Critical      0.06       35.89          14.72
# 9422        9422   20276       Critical      0.00        3.34           7.49
# 9423        9423   24491  Not Specified      0.08      550.98          45.70
# 9424        9424   25914           High      0.10      105.98          13.99
# 9425        9425   24492  Not Specified      0.09        7.78           2.50
#
# ...

# %%
df[df["Ship Mode"]=="Regular Air"].value_counts().mean()
# Out:
# 1.0

# %%
df.describe()
# Out:
#         Unnamed: 0        Row ID     Discount   Unit Price  Shipping Cost  \
# count  9426.000000   9426.000000  9426.000000  9426.000000    9426.000000
# mean   4712.500000  20241.015277     0.049628    88.303686      12.795142
# std    2721.196152   6101.890965     0.031798   281.540982      17.181203
# min       0.000000      2.000000     0.000000     0.990000       0.490000
# 25%    2356.250000  19330.250000     0.020000     6.480000       3.192500
# 50%    4712.500000  21686.500000     0.050000    20.990000       6.050000
# 75%    7068.750000  24042.750000     0.080000    85.990000      13.990000
# max    9425.000000  26399.000000     0.250000  6783.020000     164.730000
#
#        Customer ID  Product Base Margin   Postal Code        Profit  \
# count  9426.000000          9354.000000   9426.000000   9426.000000
# mean   1738.422236             0.512189  52446.327286    139.236410
# std     979.167197             0.135229  29374.597802    998.486483
# ...

# %%
df[df["date_differnce_till_order"]>=10]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Row ID, Order Priority, Discount, Unit Price, Shipping Cost, Customer ID, Customer Name, Ship Mode, Customer Segment, Product Category, Product Sub-Category, Product Container, Product Name, Product Base Margin, Region, State or Province, City, Postal Code, Order Date, Ship Date, Profit, Quantity ordered new, Sales, Order ID, Manager_of_region, Order_Day_of, ship_day_of, date_differnce_till_order]
# Index: []
#
# [0 rows x 29 columns]

# %%
df
# Out:
#       Unnamed: 0  Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 0              0   18606  Not Specified      0.01        2.88           0.50
# 1              1   20847           High      0.01        2.84           0.93
# 2              2   23086  Not Specified      0.03        6.68           6.15
# 3              3   23087  Not Specified      0.01        5.68           3.60
# 4              4   23088  Not Specified      0.00      205.99           2.50
# ...          ...     ...            ...       ...         ...            ...
# 9421        9421   20275       Critical      0.06       35.89          14.72
# 9422        9422   20276       Critical      0.00        3.34           7.49
# 9423        9423   24491  Not Specified      0.08      550.98          45.70
# 9424        9424   25914           High      0.10      105.98          13.99
# 9425        9425   24492  Not Specified      0.09        7.78           2.50
#
# ...

# %%
df
# Out:
#       Unnamed: 0  Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 0              0   18606  Not Specified      0.01        2.88           0.50
# 1              1   20847           High      0.01        2.84           0.93
# 2              2   23086  Not Specified      0.03        6.68           6.15
# 3              3   23087  Not Specified      0.01        5.68           3.60
# 4              4   23088  Not Specified      0.00      205.99           2.50
# ...          ...     ...            ...       ...         ...            ...
# 9421        9421   20275       Critical      0.06       35.89          14.72
# 9422        9422   20276       Critical      0.00        3.34           7.49
# 9423        9423   24491  Not Specified      0.08      550.98          45.70
# 9424        9424   25914           High      0.10      105.98          13.99
# 9425        9425   24492  Not Specified      0.09        7.78           2.50
#
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0        Row ID     Discount   Unit Price  Shipping Cost  \
# count  9426.000000   9426.000000  9426.000000  9426.000000    9426.000000
# mean   4712.500000  20241.015277     0.049628    88.303686      12.795142
# std    2721.196152   6101.890965     0.031798   281.540982      17.181203
# min       0.000000      2.000000     0.000000     0.990000       0.490000
# 25%    2356.250000  19330.250000     0.020000     6.480000       3.192500
# 50%    4712.500000  21686.500000     0.050000    20.990000       6.050000
# 75%    7068.750000  24042.750000     0.080000    85.990000      13.990000
# max    9425.000000  26399.000000     0.250000  6783.020000     164.730000
#
#        Customer ID  Product Base Margin   Postal Code        Profit  \
# count  9426.000000          9354.000000   9426.000000   9426.000000
# mean   1738.422236             0.512189  52446.327286    139.236410
# std     979.167197             0.135229  29374.597802    998.486483
# ...

# %%
df
# Out:
#       Unnamed: 0  Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 0              0   18606  Not Specified      0.01        2.88           0.50
# 1              1   20847           High      0.01        2.84           0.93
# 2              2   23086  Not Specified      0.03        6.68           6.15
# 3              3   23087  Not Specified      0.01        5.68           3.60
# 4              4   23088  Not Specified      0.00      205.99           2.50
# ...          ...     ...            ...       ...         ...            ...
# 9421        9421   20275       Critical      0.06       35.89          14.72
# 9422        9422   20276       Critical      0.00        3.34           7.49
# 9423        9423   24491  Not Specified      0.08      550.98          45.70
# 9424        9424   25914           High      0.10      105.98          13.99
# 9425        9425   24492  Not Specified      0.09        7.78           2.50
#
# ...

# %%
df
# Out:
#       Unnamed: 0  Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 0              0   18606  Not Specified      0.01        2.88           0.50
# 1              1   20847           High      0.01        2.84           0.93
# 2              2   23086  Not Specified      0.03        6.68           6.15
# 3              3   23087  Not Specified      0.01        5.68           3.60
# 4              4   23088  Not Specified      0.00      205.99           2.50
# ...          ...     ...            ...       ...         ...            ...
# 9421        9421   20275       Critical      0.06       35.89          14.72
# 9422        9422   20276       Critical      0.00        3.34           7.49
# 9423        9423   24491  Not Specified      0.08      550.98          45.70
# 9424        9424   25914           High      0.10      105.98          13.99
# 9425        9425   24492  Not Specified      0.09        7.78           2.50
#
# ...

# %%
df=pd.read_excel(r"C:\Users\RJ\Desktop\Practice Resourses\Superstore_USA.xlsx")

# %%
df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
post=df.drop_duplicates("Postal Code")

# %%
post
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 7      20228  Not Specified      0.02      500.98          26.00            5
# 9      24782           High      0.01       90.24           0.99            6
# 13     21866           High      0.05       12.28           4.86            7
# ...      ...            ...       ...         ...            ...          ...
# 9381   23093         Medium      0.04       12.95           4.98         3389
# 9393   18988            Low      0.02      276.20          24.49         3396
# 9400   20624            Low      0.00     1270.99          19.99         3397
# 9406   22599       Critical      0.01      177.98           0.99         3398
# 9413   24911         Medium      0.10        9.38           4.93         3400
#
# ...

# %%
df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
profit_by_region=df.groupby("Region")["Profit"].sum()

# %%
profit_by_region
# Out:
# Region
# Central    519825.567067
# East       377566.186045
# South      104201.192420
# West       310849.453897
# Name: Profit, dtype: float64

# %%
max_profit=profit_by_region.idxmax()

# %%
max_profit
# Out:
# 'Central'

# %%
discount_=df.groupby("Region")["Discount"].max()

# %%
discount_
# Out:
# Region
# Central    0.25
# East       0.10
# South      0.10
# West       0.10
# Name: Discount, dtype: float64

# %%
max_discount=discount_.idxmax()

# %%
max_discount
# Out:
# 'Central'

# %%
cus_profit=df.groupby("Customer Name")["Profit"].sum()

# %%
cus_profit
# Out:
# Customer Name
# Aaron Davies Bruce       1224.810500
# Aaron Day                 -98.126000
# Aaron Dillon               33.473200
# Aaron Fuller Davidson      33.988950
# Aaron Riggs              1081.305600
#                             ...
# Zachary House             -13.962600
# Zachary Maynard          -390.768000
# Zachary Potter              9.500600
# Zachary Wu                 86.658029
# Zachary Yu                -55.689920
# Name: Profit, Length: 2703, dtype: float64

# %%
cus_pro=cus_profit.idxmax()

# %%
cus_pro
# Out:
# 'Andrea Shaw'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[200], line 1
# ----> 1 df.cus_profit.max()
#
# File E:\AnacondaDistribution\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'cus_profit'

# %%
df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
loss_cate=df[df["Profit"]<0].groupby("Product Category")["Profit"].sum()

# %%
if len(loss_cate)>=2:
    loss_category=loss_cate.sort_values(ascending=False).index[2]
    print(loss_category)
else:
    print("not enough product category")
# Out:
# Furniture

# %%
loss_cate
# Out:
# Product Category
# Furniture         -410464.845289
# Office Supplies   -393433.301145
# Technology        -358842.689349
# Name: Profit, dtype: float64

# %%
loss_cate
# Out:
# Product Category
# Furniture         -410464.845289
# Office Supplies   -393433.301145
# Technology        -358842.689349
# Name: Profit, dtype: float64

# %%
df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...
